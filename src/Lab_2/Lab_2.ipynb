# %% [markdown]
# # Yelp Web Scraping
#
# **In the practice we will use requests+json to develop a simple but efficient Yelp crawler (offical API based)**
#
# In lots of situation, we can get data from popular platforms such as google map, Yelp etc. using their official Web APIs. To use these Web APIs, you will need a developer account for the target platform, and in general, there are QPS and amount limit for the free quota. Of course you can always buy more quota if your want (a little expensive for students).
#
# For google and Yelp's APIs such as Yelp's "Bussiness Search", each request will just return a small amount of data (the entire data is divied into a bunch of pages), and there is a limitation of the total results you can get in a single research. For example, in Seattle, WA, there may be 30000 restuarants, however in a single search your can get no more than 1000 resturants, and the result is divided into 20 pages, each page contains 50 records (one request, one page). To approximate the real number "30,000", you will need advanced techniques such as grid search algorithm or recursive search algorithm. We wouldn't learn about thse advanced techniques in this turtorial, but we will manage to get the allowed max num in one single serach by simply retrieve data in different pages.

# %%
#Read the following source code to learn basic skills of developing a web crawler based on official API

#pip install requests json pandas
#For colab, requests,json,pandas are pre-installed

import requests
import csv
import json
import math
import pandas as pd
import time


# API Path
BUSINESS_SEARCH="https://api.yelp.com/v3/businesses/search"
REVIEWS="https://api.yelp.com/v3/businesses/id/reviews"

# API Key (Please change to your own key)
# See https://www.yelp.com/developers/v3/manage_app
API_KEY='yWY2oA2ERfUifRPAPcN9OO9k3AT1qzbup94NbExuABZoHkzDHtVjWzy1XTxKS0DFVtmsrNSPMN7A_ToLNC1UJnOoM5ovlZ_mlBXu6Uyqb-jptttCbRPjIiZFOjshY3Yx'
HEADER = {
      'Authorization': 'Bearer %s' % API_KEY,
  }

# constant params
MAX=50
LIMIT=10


def yelp_search(term='business',location='Green Lake, Seattle, WA',pause=0.25,includeComments=False):
  """Extract information of Yelp (By Yifan)

  Retrieves basic information (max 1000 items) and attached comments (max 3 comments each item) of Yelp search
  Key reference: https://www.yelp.com/developers/documentation/v3/business_search
  
  Args:
    term: Search term, for example "food" or "restaurants". The term may also be business names, such as "Starbucks".
    location: Geographic area to be used when searching for businesses. Examples: "New York City", "NYC", "350 5th Ave, New York, NY 10118". Businesses returned in the response may not be strictly within the specified location.
    pause: Speed contral, single pause time (s) for avoiding overheated QPS
    includeComments: whether to retrived attached comments

  Returns:
    A pandas dataframe
    if includesComments=False: the dataframe will contains 12 columns(content_id,name,rating,reviews,phone,address,city,state,country,postcode,latitude,longitude)
    else: the dataframe will contains addtional 5 columns (comment_id,user_id,user_name,user_rating,comment)
    A list, which contains 9 items (content_id,name,rate,review,tags,address,city,state,postcode)
    the content_id is important - we need it to further request comments
  """

  params = {
        'term': term, 
        'location': location,
        'limit': LIMIT,
        }
  #determine how many terms are at the location and how many we can get
  # the "total" in current API is limited to 240, in other words, it no longer reflects the real number of businesses in the area
  # if it works, the alternative code for "total=MAX" should work
  #--------------------alternative code----------
  # total= json.loads(requests.request('GET',BUSINESS_SEARCH, headers=headers,params=params).text)['total']
  # print('there are {} {} at {}'.format(total,term,location))
  # if total>MAX:
  #   total=MAX
  
  total=MAX
  
  #calculate the offset list we need to retrive the research list
  offsets=[i*LIMIT for i in range(math.ceil(total/LIMIT))]
  
  # initial the result list
  rst=[]
  print('**********Start**********')
  #retrive data according to offset list
  for offset in offsets:
    print("Retrieving: {}/{}".format(offset,total))
    time.sleep(pause)
    params['offset']=offset
    response = requests.request('GET',BUSINESS_SEARCH, headers=HEADER,params=params)
    data = json.loads(response.text)['businesses'] # turn the responese's json string to dictionary
    for item in data:             # extract data we need in loop
      # get basic information
      content_id=item['id']
      name=item['name']
      rating=item['rating']
      reviews=item['review_count']
      phone=item['phone']
      address=item['location']['address1']
      city=item['location']['city']
      state=item['location']['state']
      country=item['location']['country']
      postcode=item['location']['zip_code']
      latitude=item['coordinates']['latitude']
      longitude=item['coordinates']['longitude']
      rst.append([content_id,name,rating,reviews,phone,address,city,state,country,postcode,latitude,longitude])
  # rst=rst[0:total] #drop redundant duplicates which is due to the mechanism of offset
  # reformate the result list to a pandas dataframe
  df=pd.DataFrame(data=rst,columns=["content_id","name","rating","reviews",
                                    "phone","address","city","state","country",
                                    "postcode","latitude","longitude"])
  df.drop_duplicates('content_id','first',inplace=True)
  print("{} {} at {} Retrieved.".format(len(df),term,location))
  #retrive additional comments
  if includeComments:
    rst=[]
    for i,content_id in zip(range(len(df['content_id'])),df['content_id']):
      if (i+1)%5==0:
        print("Comments Retrieving: {}/{}".format(i+1,len(df['content_id'])))
        time.sleep(pause)
      response = requests.request('GET',REVIEWS.replace('id',content_id), headers=HEADER)
      data = json.loads(response.text)['reviews']
      cmts=[]
      for comment in data:
        comment_id=comment['id']
        user_id=comment['user']['id']
        user_name=comment['user']['name']
        user_rating=comment['rating']
        comment=comment['text']
        rst.append([content_id,comment_id,user_id,user_name,user_rating,comment])
    cdf=pd.DataFrame(data=rst,columns=["content_id","comment_id","user_id",
                                     "user_name","user_rating","comment"])
    print('{} attached comments retrieved.'.format(len(cdf)))
    df=pd.merge(df,cdf,on='content_id')
  print('**********FINISH**********')
  return df

# %%
#Excute Demo: Extract basic information of Yelp search result
MAX=50 # Just for demo to reduce API usage. Please delete this line in real practice, or set "MAX=1000". 
df1=yelp_search(term='business',location='Green Lake, Seattle, WA',pause=0.25,includeComments=False)
df1
# Out:
# **********Start**********
# Retrieving: 0/50
# Retrieving: 10/50
# Retrieving: 20/50
# Retrieving: 30/50
# Retrieving: 40/50
# 50 business at Green Lake, Seattle, WA Retrieved.
# **********FINISH**********
# <ipython-input-3-2ef9d7e88a82>:99: FutureWarning: In a future version of pandas all arguments of DataFrame.drop_duplicates except for the argument 'subset' will be keyword-only
#   df.drop_duplicates('content_id','first',inplace=True)
#                 content_id                                          name  \
# 0   OuxP_uWXB-YG8EYGVOX7FA                     Seattle CPA Professionals
# 1   lY3YoAx3XmBnlOv8MKysXw                         Clear Sky Bookkeeping
# 2   m_x3dvMGCvXF0Fj6AeauoA                                        Morsel
# 3   L2bswPTN84fdTny7y1EYRA                                Works Progress
# 4   75nF3g8q4RQHD17yQQ47HQ                  The Wise Owl Books and Music
# 5   q_rN813GkQD8ryeT9QeWug                            Stretch and Staple
# 6   PQPVZyr-ssrcF28c680O9Q                          Clear Skies Cleaning
# 7   0lHUizq6U2UIf4KLPTUdng                            Up Time Technology
# 8   PpOAc_6PXtC8gHmae4P1Jw                       Tula's Cleaning Service
# 9   MQRXvwKGLvkxhEmWN8Tdkg  David Drake - Windermere Property Management
# 10  wVDlcXLfWyJLrjwshXM3GQ                                 Ride Bicycles
# 11  kFJtNUqPDDvuqizj98PDNw                            Spin Digital Print
# 12  _oD1-6wG5Yxt1TvJ-H4P-A               The Wick Motorcycles And Coffee
# 13  Pn_MckGlqVQz-dhHEeN4yQ                 Huddleston Tax CPAs - Seattle
# 14  upguVkDNCVH6Z8Hdp_WwZQ                                   The Phinery
# 15  Q0Hqo5Aw-AyWMmpUICPGEQ                       Parker Eco Pest Control
# 16  _tdlSmj07UQ4vkVSMQ0c1A                                   Real Basics
# 17  018rYSHznjI1lzEU9PDavA                                           Mkt
# 18  9mbJ1vOm00ahLIkmzYufnA                                      Mail Etc
# 19  VARUIZaMddCPjorl9Yntmw                            RainCity, CPA PLLC
# 20  rFLInyxC3azZIykYS3WADw                                   Baraka Gems
# 21  syGzHHQn75ID_ViiVTn8NQ                                School of Bike
# 22  PXRDHnrq1ce5qkx_Oq7T0g                         Ferguson Tax Services
# 23  SdgMOGDAmgMrinYCZlCvKA                          Joseph & Hetrick LLC
# 24  SN0ptAGjSbMeYq1sOvi1Kw                                Studio 3 Signs
# 25  6R4rcffeehMHKuXVF9dzVg                              Progressive Tech
# 26  kw8da9fEVadUdLclDWIkZw                                 Wessco Blinds
# 27  IQDUN1MXkekjkSFSpyMhmg                  Seattle Green Earth Cleaning
# 28  TNoPtGl1yDeLercz_ppRYQ                             Blue Poppy Floral
# 29  85BscxsTy6T9todcfJw45Q                                       The Inc
# 30  nsYwNT1gYdYddyFIJp22JA                    Green Lake Computer Repair
# 31  8SoG4ilLiu-eopmjhmHGvw                          Inkfancy Letterpress
# 32  Ysm_SeAp7emGRqXnYFYjFw                              Rams Copy Center
# 33  6DqomM_1Fe64RQRkndQb6w                        Phinney Ridge Painting
# 34  IAumYw1Hs-cnHqLeHQWB7Q                     University License Agency
# 35  kANGdiAVDVJwrb6MKj9NJw                       Open Space Design Decks
# 36  Fithy2BSBF54zxVHBs75fw                              Raincap Electric
# 37  ftJ0h05irx1aYOeampH7Fw                                       Retreat
# 38  nF2-7h6bq3RsMKM9a1XkwQ                       Seattle Rubbish Removal
# 39  6WLwfrdZQS3eJ1mZ50kx0g                  Jay's Dry Cleaners Roosevelt
# 40  _VDeDLvjbEJbwoZ4PZu1sg                           Swanson Shoe Repair
# 41  c7SjSJqGDRzOd_d2A41zVw                             Steel Guarde, LLC
# 42  yFtLu1uRqAPEDGE16jmr8A                                 Fremont Space
# 43  XYvBANOlXkB79IYN3NE-Yw                             Ravenna Interiors
# 44  51UhifPO-VRm-GRmaSyqyQ                            Ultra Dry Cleaning
# 45  tZOv2vPC72VSSdQhow5sJg          T-Shirt Madness Silk Screen Printing
# 46  VGSgUxFRLye7yD3ANBkwOw                  Bellefleur Lingerie Boutique
# 47  NEYiQDyyw_z39HsedD5A0w                         Salmon Bay Technology
# 48  cvs1xamlUI13kDDcyQoL6Q              Bedrooms & More Clearance Outlet
# 49  hxfI9X4eokmAYqqS6EpZDA              Adam's Moving & Delivery Service
#
#     rating  reviews         phone                  address     city state  \
# 0      4.5       25  +12064207329           559 NE 80th St  Seattle    WA
# 1      5.0        4  +14252432029                     None  Seattle    WA
# 2      4.5     1155  +12062680154   5000 University Way NE  Seattle    WA
# 3      5.0       10  +12064661624         8001 14th Ave NE  Seattle    WA
# 4      5.0        3  +12065803211           2223 N 56th St  Seattle    WA
# 5      4.5       41  +12066079277     8005 Greenwood Ave N  Seattle    WA
# 6      5.0      136  +12066697706                     None  Seattle    WA
# 7      4.5       35  +12065471817           2408 N 45th St  Seattle    WA
# 8      5.0       31  +12067870805        8800 Nesbit Ave N  Seattle    WA
# 9      5.0       21  +12063946614           819 NE 65th St  Seattle    WA
# 10     4.5       64  +12069857433    6405 Roosevelt Way NE  Seattle    WA
# 11     5.0        8  +12065224777                           Seattle    WA
# 12     5.0        3  +12063833374        7409 Aurora Ave N  Seattle    WA
# 13     4.5       12  +14254836600          4500 9th Ave NE  Seattle    WA
# 14     5.0        9  +12067896512     7601 Greenwood Ave N  Seattle    WA
# 15     5.0      141  +18003261698        7323 Aurora Ave N  Seattle    WA
# 16     5.0        9  +12063908082            135 N 75th St  Seattle    WA
# 17     4.5      342  +14256236970           2108 N 55th St  Seattle    WA
# 18     4.0       13  +12065274140   4730 University Way NE  Seattle    WA
# 19     4.0       31  +12064025266  4300B University Way NE  Seattle    WA
# 20     5.0      226  +12067831313     8218 Greenwood Ave N  Seattle    WA
# 21     5.0       23  +12066320111      4516 Meridian Ave N  Seattle    WA
# 22     4.5       23  +12065525213          155 NE 100th St  Seattle    WA
# 23     5.0        5  +12063138864                           Seattle    WA
# 24     5.0       12  +12066228204          1117 NW 54th St  Seattle    WA
# 25     4.5      173  +12065258324    6319 Roosevelt Way NE  Seattle    WA
# 26     4.0       43  +12062855455         210 Nickerson St  Seattle    WA
# 27     5.0      137  +12065954209          1037 NE 65th St  Seattle    WA
# 28     5.0       29  +12069920739         8507 35th Ave NE  Seattle    WA
# 29     5.0        1  +12066595978           111 NE 80th St  Seattle    WA
# 30     5.0        4  +12067751526            949 N 76th St  Seattle    WA
# 31     5.0        2  +12064843852                           Seattle    WA
# 32     4.0       33  +12066326630   4336 University Way NE  Seattle    WA
# 33     4.5       57  +12063711441         922 NW Leary Way  Seattle    WA
# 34     4.0       65  +12065222166    5615 Roosevelt Way NE  Seattle    WA
# 35     5.0       20  +12067718882                     None  Seattle    WA
# 36     5.0       18  +12063970016           2315 N 65th St  Seattle    WA
# 37     3.5      404  +12066943045  6900 E Green Lake Way N  Seattle    WA
# 38     5.0      456  +12062972900                           Seattle    WA
# 39     4.0       87  +12064535930              801 NE 65th  Seattle    WA
# 40     4.5      157  +12066333434           2305 N 45th St  Seattle    WA
# 41     4.5       73  +12068122230         5500 14th Ave NW  Seattle    WA
# 42     5.0        3  +12065477722            600 N 36th St  Seattle    WA
# 43     4.0       13  +12065255794          2251 NE 65th St  Seattle    WA
# 44     4.0       33  +12065276600      401 NE Ravenna Blvd  Seattle    WA
# 45     5.0       10  +12064278720           945 NW 51st St  Seattle    WA
# 46     4.5       67  +12065450222        3504 Fremont Pl N  Seattle    WA
# 47     4.5       14  +12069059520    4601 Shilshole Ave NW  Seattle    WA
# 48     4.5        7  +12065230062           300 NE 45th St  Seattle    WA
# 49     4.5      826  +12062511725           130 NE 95th St  Seattle    WA
#
#    country postcode   latitude   longitude
# 0       US    98115  47.686613 -122.320400
# 1       US    98103  47.660009 -122.342557
# 2       US    98105  47.665441 -122.312814
# 3       US    98115  47.686840 -122.313617
# 4       US    98103  47.668829 -122.331963
# 5       US    98133  47.687095 -122.355302
# 6       US    98107  47.689575 -122.354844
# 7       US    98103  47.661575 -122.329643
# 8       US    98112  47.692540 -122.343140
# 9       US    98115  47.675610 -122.319092
# 10      US    98115  47.675156 -122.317262
# 11      US    98103  47.657180 -122.348930
# 12      US    98103  47.683060 -122.344670
# 13      US    98105  47.661740 -122.318070
# 14      US    98103  47.684297 -122.355674
# 15      US    98103  47.682384 -122.344926
# 16      US    98103  47.683064 -122.356392
# 17      US    98103  47.668695 -122.332951
# 18      US    98105  47.663969 -122.312759
# 19      US    98105  47.659927 -122.312842
# 20      US    98103  47.689011 -122.355115
# 21      US    98103  47.662045 -122.333372
# 22      US    98125  47.700820 -122.326880
# 23      US    98115  47.686661 -122.291145
# 24      US    98107  47.667650 -122.371600
# 25      US    98115  47.674807 -122.317507
# 26      US    98109  47.647608 -122.352462
# 27      US    98115  47.675654 -122.315894
# 28      US    98115  47.690460 -122.290960
# 29      US    98115  47.686430 -122.327930
# 30      US    98103  47.683860 -122.345060
# 31      US    98103  47.656680 -122.348620
# 32      US    98105  47.660831 -122.312826
# 33      US    98107  47.663771 -122.369957
# 34      US    98105  47.669840 -122.317380
# 35      US    98103  47.673315 -122.342544
# 36      US    98103  47.675780 -122.330150
# 37      US    98115  47.678518 -122.326537
# 38      US    98103  47.673315 -122.342544
# 39      US    98115  47.675643 -122.319530
# 40      US    98103  47.661175 -122.331017
# 41      US    98107  47.669070 -122.373170
# 42      US    98103  47.651616 -122.351058
# 43      US    98115  47.675580 -122.303600
# 44      US    98115  47.678307 -122.324959
# 45      US    98107  47.665499 -122.370581
# 46      US    98103  47.650820 -122.350216
# 47      US    98107  47.661712 -122.379867
# 48      US    98105  47.661580 -122.324870
# 49      US    98115  47.698220 -122.327030

# %%
#Excute Demo: Extract basic information with comments of Yelp search result
MAX=10 # Just for demo to reduce API usage. Please delete this line in real practice, or set "MAX=1000". 
df1=yelp_search(term='restaurants',location='Green Lake, Seattle, WA',pause=0.25,includeComments=True)
df1
# Out:
# **********Start**********
# Retrieving: 0/10
# <ipython-input-3-2ef9d7e88a82>:99: FutureWarning: In a future version of pandas all arguments of DataFrame.drop_duplicates except for the argument 'subset' will be keyword-only
#   df.drop_duplicates('content_id','first',inplace=True)
# 10 restaurants at Green Lake, Seattle, WA Retrieved.
# Comments Retrieving: 5/10
# Comments Retrieving: 10/10
# 30 attached comments retrieved.
# **********FINISH**********
#                 content_id                                   name  rating  \
# 0   Gn5erxCRML47GgbGYdxzFA                                 Bongos     4.5
# 1   Gn5erxCRML47GgbGYdxzFA                                 Bongos     4.5
# 2   Gn5erxCRML47GgbGYdxzFA                                 Bongos     4.5
# 3   RS-Hlsx7k90m5QODHDs5Cg                              Tapas Lab     4.5
# 4   RS-Hlsx7k90m5QODHDs5Cg                              Tapas Lab     4.5
# 5   RS-Hlsx7k90m5QODHDs5Cg                              Tapas Lab     4.5
# 6   DgNKaOrCZg4CB51QY2DHMQ                              Eight Row     4.5
# 7   DgNKaOrCZg4CB51QY2DHMQ                              Eight Row     4.5
# 8   DgNKaOrCZg4CB51QY2DHMQ                              Eight Row     4.5
# 9   MR_l59qW3luE161L6_dPgQ                   Restaurant Christine     4.5
# 10  MR_l59qW3luE161L6_dPgQ                   Restaurant Christine     4.5
# 11  MR_l59qW3luE161L6_dPgQ                   Restaurant Christine     4.5
# 12  018rYSHznjI1lzEU9PDavA                                    Mkt     4.5
# 13  018rYSHznjI1lzEU9PDavA                                    Mkt     4.5
# 14  018rYSHznjI1lzEU9PDavA                                    Mkt     4.5
# 15  hGTtY65Z2fZLkLQQDhxbYg                    Toast Mi Green Lake     4.5
# 16  hGTtY65Z2fZLkLQQDhxbYg                    Toast Mi Green Lake     4.5
# 17  hGTtY65Z2fZLkLQQDhxbYg                    Toast Mi Green Lake     4.5
# 18  6bsvnSef1lsaW76slfBPjA                        Greenlake Grill     3.5
# 19  6bsvnSef1lsaW76slfBPjA                        Greenlake Grill     3.5
# 20  6bsvnSef1lsaW76slfBPjA                        Greenlake Grill     3.5
# 21  KOLMVwoygn3Wqfw6CMrqaw  Noi Thai Cuisine - Green Lake Seattle     4.5
# 22  KOLMVwoygn3Wqfw6CMrqaw  Noi Thai Cuisine - Green Lake Seattle     4.5
# 23  KOLMVwoygn3Wqfw6CMrqaw  Noi Thai Cuisine - Green Lake Seattle     4.5
# 24  LAj25s5eeEP9Tarl-pEzYg                    Mykonos Greek Grill     4.5
# 25  LAj25s5eeEP9Tarl-pEzYg                    Mykonos Greek Grill     4.5
# 26  LAj25s5eeEP9Tarl-pEzYg                    Mykonos Greek Grill     4.5
# 27  nc_51O9QgcmqVePj9VLNuw                         Ong Lam Bistro     5.0
# 28  nc_51O9QgcmqVePj9VLNuw                         Ong Lam Bistro     5.0
# 29  nc_51O9QgcmqVePj9VLNuw                         Ong Lam Bistro     5.0
#
#     reviews         phone                    address     city state country  \
# 0      1215  +12064208548          6501 Aurora Ave N  Seattle    WA      US
# 1      1215  +12064208548          6501 Aurora Ave N  Seattle    WA      US
# 2      1215  +12064208548          6501 Aurora Ave N  Seattle    WA      US
# 3       235  +12067751744       7012 Woodlawn Ave NE  Seattle    WA      US
# 4       235  +12067751744       7012 Woodlawn Ave NE  Seattle    WA      US
# 5       235  +12067751744       7012 Woodlawn Ave NE  Seattle    WA      US
# 6       159  +12062943178       7102 Woodlawn Ave NE  Seattle    WA      US
# 7       159  +12062943178       7102 Woodlawn Ave NE  Seattle    WA      US
# 8       159  +12062943178       7102 Woodlawn Ave NE  Seattle    WA      US
# 9        41  +12064204781             2227 N 56th St  Seattle    WA      US
# 10       41  +12064204781             2227 N 56th St  Seattle    WA      US
# 11       41  +12064204781             2227 N 56th St  Seattle    WA      US
# 12      342  +14256236970             2108 N 55th St  Seattle    WA      US
# 13      342  +14256236970             2108 N 55th St  Seattle    WA      US
# 14      342  +14256236970             2108 N 55th St  Seattle    WA      US
# 15       65  +12064025546       7130 Woodlawn Ave NE  Seattle    WA      US
# 16       65  +12064025546       7130 Woodlawn Ave NE  Seattle    WA      US
# 17       65  +12064025546       7130 Woodlawn Ave NE  Seattle    WA      US
# 18      554  +12067296179     7200 E Green Lake Dr N  Seattle    WA      US
# 19      554  +12067296179     7200 E Green Lake Dr N  Seattle    WA      US
# 20      554  +12067296179     7200 E Green Lake Dr N  Seattle    WA      US
# 21      101  +12065373777  7900 East Green Lake Dr N  Seattle    WA      US
# 22      101  +12065373777  7900 East Green Lake Dr N  Seattle    WA      US
# 23      101  +12065373777  7900 East Green Lake Dr N  Seattle    WA      US
# 24      389  +12065238929             310 NE 72nd St  Seattle    WA      US
# 25      389  +12065238929             310 NE 72nd St  Seattle    WA      US
# 26      389  +12065238929             310 NE 72nd St  Seattle    WA      US
# 27       13  +12067373737            1010 NE 66th St  Seattle    WA      US
# 28       13  +12067373737            1010 NE 66th St  Seattle    WA      US
# 29       13  +12067373737            1010 NE 66th St  Seattle    WA      US
#
#    postcode   latitude   longitude              comment_id  \
# 0     98103  47.676745 -122.346925  gsqMRGFcQqEk_8_AU4xh6w
# 1     98103  47.676745 -122.346925  Bfu8DA-2VJHeaptKM2drdg
# 2     98103  47.676745 -122.346925  fd2q02UYdyxfjiu8PHPEbg
# 3     98115  47.679340 -122.324390  vCpqMiCoZzJaF9J4nSBWDA
# 4     98115  47.679340 -122.324390  t2TXbaBTfGA5U2IqPboJwQ
# 5     98115  47.679340 -122.324390  TSJx05vVg2n6eH1iGcPXOQ
# 6     98115  47.680120 -122.324370  mBKSQGs-0Sn2lcEwyhXNSQ
# 7     98115  47.680120 -122.324370  YUQmZRh6iPYmupvQQs2mXA
# 8     98115  47.680120 -122.324370  u1FArf4TjMNYfdZwXwEJ5A
# 9     98103  47.668760 -122.331830  jZe0guWQWfgeG_KEQaPbEg
# 10    98103  47.668760 -122.331830  EQT_YEnMD8xsCrp5dtDTpQ
# 11    98103  47.668760 -122.331830  3Op3zfiDemUKg7DOwc1pYg
# 12    98103  47.668695 -122.332951  8ktebozdeiKdqAERdzyTzQ
# 13    98103  47.668695 -122.332951  CfOPeEPjfYhpbLXMdQaMCQ
# 14    98103  47.668695 -122.332951  sMJqSfi3KuaS67ZOflh4lA
# 15    98115  47.680280 -122.324420  zwrp2pwZTrlR13BcV18f-g
# 16    98115  47.680280 -122.324420  XjckD5HBFBCzuSEt7F9ymg
# 17    98115  47.680280 -122.324420  YpMzk71vEr6nu6fqQKzgZg
# 18    98115  47.680490 -122.325710  oRwuFXGzy6IZPan2r6xEzQ
# 19    98115  47.680490 -122.325710  oYm_GCDQIi5rOUp_BJ14GA
# 20    98115  47.680490 -122.325710  2klrW-XUTJfUIVVeOnXP1Q
# 21    98103  47.685900 -122.337300  lRuzxub10YvXieG4khZygQ
# 22    98103  47.685900 -122.337300  QTIABUOE5LI5W2rNvl1L9Q
# 23    98103  47.685900 -122.337300  Fpm1KtnwZC1o3jivgKOVRQ
# 24    98115  47.680560 -122.325310  jk5_FTcwi6VYUnafk_wFxw
# 25    98115  47.680560 -122.325310  UzmVjEFT0mnzHvY0v3ENeA
# 26    98115  47.680560 -122.325310  2YzHuMtW8ioTTrsPR7tttQ
# 27    98115  47.676710 -122.316740  B0u3gxbTZuSTpnuuhWKT5w
# 28    98115  47.676710 -122.316740  7n-tWsIZZ6_-ovowQSoLhg
# 29    98115  47.676710 -122.316740  f8IDEHgj8xb9f5fnw5kt1A
#
#                    user_id     user_name  user_rating  \
# 0   2Mnd6FEaHuI1p01f-LmG1g     Ana K  S.            5
# 1   LMBh_gkkp_tHQuIw72l65g       Luba K.            5
# 2   VGPcMHDu2Ni0qzJtlprNXw       Katy H.            4
# 3   iBim7ih7ue_EGczvtHVU7Q         Vy M.            5
# 4   fDPw0phD3xzEdMrAP0iutw       Vita L.            4
# 5   X75ftsvDkgvjcjhjrMuakw       Will L.            5
# 6   C6LV0p8L6IfBfh1YFRkWzQ  Elizabeth L.            5
# 7   weG2lafFtd00B9XklzHfWg      Steve W.            2
# 8   2E9njyTMI0qzQOKhe8mHDg   Benjamin H.            4
# 9   mGmLgnaZfLwuO93Bsc-Ghw      Rikki N.            5
# 10  0oFGP8mu4IjNhL1TGVVrvw      Molly I.            3
# 11  vRuHPM06W9iQJXK8XHbC3Q      Peter L.            5
# 12  A8BMl32898Uqryd1MjMS9A       Rona L.            5
# 13  Epv3qVAFnufI7yP0-oSAhQ      Stacy S.            5
# 14  pbJBu2t_9oiX_3iG4uvR8w          B M.            5
# 15  GBsrTASbxWg_6NSyDRAHaw      Adela R.            5
# 16  A5NNn6xQLniTeO6pdazvBQ      Alice L.            4
# 17  QHyuhqjGFsroQppjBBhEBA      Diana W.            5
# 18  539MWjOZYGhDgn4mgUVVwA    Madison P.            4
# 19  F2ZrQ5QullYOQZkbSFhWDA    Kristen B.            5
# 20  MhoNjFAqqEz7Ax-WIk8i9Q    Roxanne R.            4
# 21  WmbIEo46OoSFyg4atUwrbg     Alyssa M.            5
# 22  EzHVkq_aplBXpLre5lqJ8g        Liz S.            3
# 23  rW1ZlneQoLQUD9NtdmNeiw       Thuy N.            4
# 24  B0_sbv2OdY-dgmN6wlrZYQ   Courtney J.            5
# 25  u31zMUh4P8LO2HmVlHvnNA     Selena S.            4
# 26  _jqTa-3-fqmBxnkANJHtFw      Brian F.            4
# 27  qLL3o0W9AhRFBuP7kD5ovQ      David N.            5
# 28  iI_OrP9VLGYSg4LqPKDhlw       Mark E.            5
# 29  ivG4VgMLNGf_wF1CIA1-Ww     Spanky M.            4
#
#                                               comment
# 0   I am forever grateful to the Yelp community fo...
# 1   Yes, yes, this place is as good as everyone sa...
# 2   After hearing such good reviews I was pleasant...
# 3   Finally tried Tapas Lab and I am very pleased!...
# 4   There aren't many vegan options. I was on a da...
# 5   I've been meaning to try this place for a whil...
# 6   Outstanding farm to table prix fixe, seasonal ...
# 7   We were so looking forward to dinner here and ...
# 8   Lovely space, very nice servers. I'm told it's...
# 9   So far I've tried the pulled pork sammy with t...
# 10  Had a perfectly lovely meal at Restaurant Chri...
# 11  For my last review of the year and my 1,000th:...
# 12  Honestly, this is still one of my favorite res...
# 13  I'm an ESR fan, so I fully recognize some bias...
# 14  Great for a dinner date or drinks/small plates...
# 15  This place is AMAZING!! I've been following th...
# 16  Really solid banh mi! Their bread is so good, ...
# 17  Super fresh & thoughtfully well prepared bahn ...
# 18  THE FOOD: absolutely delicious! All came out h...
# 19  Been coming here now about a few times\na mont...
# 20  A group of my friends and I were going out for...
# 21  It is just as cute as all the social media vid...
# 22  I'd give Noi Thai 3.5 stars overall. My review...
# 23  The meal was great! Our most favorite was the ...
# 24  I was recommended to come here by my roommates...
# 25  A solid gyro, but mediocre pork souvlaki and s...
# 26  Mykonos is a family-run Greek restaurant in th...
# 27  We loved it. We came fresh off the plane from ...
# 28  TLDR: A new must try dine in spot in Roosevelt...
# 29  So this Pho is probably one many are not used ...

# %% [markdown]
# Now the following code will filter the scraped data and store the columns that we need in the next step into a new data frame with myData.

# %%
myData=df1.filter(items=['name','rating','comment', 'latitude', 'longitude'])
myData
# Out:
#                                      name  rating  \
# 0                                  Bongos     4.5
# 1                                  Bongos     4.5
# 2                                  Bongos     4.5
# 3                               Tapas Lab     4.5
# 4                               Tapas Lab     4.5
# 5                               Tapas Lab     4.5
# 6                               Eight Row     4.5
# 7                               Eight Row     4.5
# 8                               Eight Row     4.5
# 9                    Restaurant Christine     4.5
# 10                   Restaurant Christine     4.5
# 11                   Restaurant Christine     4.5
# 12                                    Mkt     4.5
# 13                                    Mkt     4.5
# 14                                    Mkt     4.5
# 15                    Toast Mi Green Lake     4.5
# 16                    Toast Mi Green Lake     4.5
# 17                    Toast Mi Green Lake     4.5
# 18                        Greenlake Grill     3.5
# 19                        Greenlake Grill     3.5
# 20                        Greenlake Grill     3.5
# 21  Noi Thai Cuisine - Green Lake Seattle     4.5
# 22  Noi Thai Cuisine - Green Lake Seattle     4.5
# 23  Noi Thai Cuisine - Green Lake Seattle     4.5
# 24                    Mykonos Greek Grill     4.5
# 25                    Mykonos Greek Grill     4.5
# 26                    Mykonos Greek Grill     4.5
# 27                         Ong Lam Bistro     5.0
# 28                         Ong Lam Bistro     5.0
# 29                         Ong Lam Bistro     5.0
#
#                                               comment   latitude   longitude
# 0   I am forever grateful to the Yelp community fo...  47.676745 -122.346925
# 1   Yes, yes, this place is as good as everyone sa...  47.676745 -122.346925
# 2   After hearing such good reviews I was pleasant...  47.676745 -122.346925
# 3   Finally tried Tapas Lab and I am very pleased!...  47.679340 -122.324390
# 4   There aren't many vegan options. I was on a da...  47.679340 -122.324390
# 5   I've been meaning to try this place for a whil...  47.679340 -122.324390
# 6   Outstanding farm to table prix fixe, seasonal ...  47.680120 -122.324370
# 7   We were so looking forward to dinner here and ...  47.680120 -122.324370
# 8   Lovely space, very nice servers. I'm told it's...  47.680120 -122.324370
# 9   So far I've tried the pulled pork sammy with t...  47.668760 -122.331830
# 10  Had a perfectly lovely meal at Restaurant Chri...  47.668760 -122.331830
# 11  For my last review of the year and my 1,000th:...  47.668760 -122.331830
# 12  Honestly, this is still one of my favorite res...  47.668695 -122.332951
# 13  I'm an ESR fan, so I fully recognize some bias...  47.668695 -122.332951
# 14  Great for a dinner date or drinks/small plates...  47.668695 -122.332951
# 15  This place is AMAZING!! I've been following th...  47.680280 -122.324420
# 16  Really solid banh mi! Their bread is so good, ...  47.680280 -122.324420
# 17  Super fresh & thoughtfully well prepared bahn ...  47.680280 -122.324420
# 18  THE FOOD: absolutely delicious! All came out h...  47.680490 -122.325710
# 19  Been coming here now about a few times\na mont...  47.680490 -122.325710
# 20  A group of my friends and I were going out for...  47.680490 -122.325710
# 21  It is just as cute as all the social media vid...  47.685900 -122.337300
# 22  I'd give Noi Thai 3.5 stars overall. My review...  47.685900 -122.337300
# 23  The meal was great! Our most favorite was the ...  47.685900 -122.337300
# 24  I was recommended to come here by my roommates...  47.680560 -122.325310
# 25  A solid gyro, but mediocre pork souvlaki and s...  47.680560 -122.325310
# 26  Mykonos is a family-run Greek restaurant in th...  47.680560 -122.325310
# 27  We loved it. We came fresh off the plane from ...  47.676710 -122.316740
# 28  TLDR: A new must try dine in spot in Roosevelt...  47.676710 -122.316740
# 29  So this Pho is probably one many are not used ...  47.676710 -122.316740

# %% [markdown]
# Now you will download data in CSV or JSON and clean.

# %% [markdown]
# # Build a nested database
#
# This is a process after cleaning the raw data
#
# The following code is a method to create a nested data by a business name. The data includes name, lat, lon, and review and the column review has two nested data of ratings and comment.
# Our particular radial dendrogram creates nodes with the column with 'name'. Note that business names and comments are stored in 'name' column at a different depth in the data hierarchy.

# %%
def add_root(df_root):
    for row in df_root.itertuples():
        yield {"name": 'review',
               "children":list(pd_to_review_dict(df_root))
        }
def pd_to_review_dict(df):
    for (name), df_name_grouped in df.groupby(["name"]):
        yield {
            "name": name,
            "latitude": df.loc[df['name'] == name, 'latitude'].iloc[0],
            "longitude": df.loc[df['name'] == name, 'longitude'].iloc[0],
            "children": list(split_line_items(df_name_grouped))
        }
        
def split_line_items(df_review):
    for row in df_review.itertuples():
        yield {
            "value": row.rating,
            "name": row.comment
        }

# %% [markdown]
# Now you will pass the data frame from the crawler into the method above by running the following code block and it will print the data in json in an output cell and name the data in json format to 'myYepData.

# %%
df_pd = pd.DataFrame(myData)
review_list = list(add_root(df_pd))
review_dict = {}
for sub_dict in review_list:
        review_dict.update(sub_dict)
print(json.dumps(review_dict, indent=4))
myYelpData=json.dumps(review_dict)
# Out:
# {
#     "name": "review",
#     "children": [
#         {
#             "name": "Bongos",
#             "latitude": 47.6767449533551,
#             "longitude": -122.346925400198,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "I am forever grateful to the Yelp community for helping us find this spot. It must feel like an echochamber of positive reviews for newcomers but this place..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "Yes, yes, this place is as good as everyone says. Trust me, I've come here 3x and it was randomly closed...and I still came back to try it...and then came..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "After hearing such good reviews I was pleasantly surprised that this food lives up to its reputation. The veggie platter was particularly amazing for..."
#                 }
#             ]
#         },
#         {
#             "name": "Eight Row",
#             "latitude": 47.68012,
#             "longitude": -122.32437,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "Outstanding farm to table prix fixe, seasonal tasting menus feature local ingredients from independent farms and orchards. Creative dishes incorporating the..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "We were so looking forward to dinner here and ultimately most of the meat dishes ended up being a disappointment. \n\nRockfish ceviche.  My first bite was..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "Lovely space, very nice servers. I'm told it's women-owned and it seemed to be mostly staffed by women, which I'm all for. My friend and I got the tasting..."
#                 }
#             ]
#         },
#         {
#             "name": "Greenlake Grill",
#             "latitude": 47.68049,
#             "longitude": -122.32571,
#             "children": [
#                 {
#                     "value": 3.5,
#                     "name": "THE FOOD: absolutely delicious! All came out hot and fresh. Everything tasted amazing and was very filling. \n\nTHE SERVICE: this is where the 4 stars come..."
#                 },
#                 {
#                     "value": 3.5,
#                     "name": "Been coming here now about a few times\na month  ! That Meatloaf is incredible super friendly staff a fan !!"
#                 },
#                 {
#                     "value": 3.5,
#                     "name": "A group of my friends and I were going out for dinner with no restaurant picked. We ended up at Greenlake Grill by walking by and seeing they didn't have a..."
#                 }
#             ]
#         },
#         {
#             "name": "Mkt",
#             "latitude": 47.6686946,
#             "longitude": -122.3329512,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "Honestly, this is still one of my favorite restaurants in Seattle. The food is always delicious, the service is always great, and I love their new outdoor..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "I'm an ESR fan, so I fully recognize some bias. However, I'm a fan because the food and service is consistently great.\n\nDinner at Mkt last night was..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "Great for a dinner date or drinks/small plates after a long work week. Has a very relaxed ambiance and wonderful customer service! Been dreaming about the..."
#                 }
#             ]
#         },
#         {
#             "name": "Mykonos Greek Grill",
#             "latitude": 47.68056,
#             "longitude": -122.32531,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "I was recommended to come here by my roommates who have raved about the food and tried it out for the first time a few weeks ago. Zarina is so sweet and I..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "A solid gyro, but mediocre pork souvlaki and sides. \n\nWe enjoyed the gyro a lot - the meat is tender and wrap comes with enough sauce and veggies to be..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "Mykonos is a family-run Greek restaurant in the Green Lake area. There is limited parking in the area so you might have to drive around the block a couple..."
#                 }
#             ]
#         },
#         {
#             "name": "Noi Thai Cuisine - Green Lake Seattle",
#             "latitude": 47.6859,
#             "longitude": -122.3373,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "It is just as cute as all the social media vides are showing! It's so bright and modern looking inside with white and gold accented colors. It has such a..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "I'd give Noi Thai 3.5 stars overall. My reviews overall lean towards the food itself, so I'm going with a 3 here--decent.\n\nI arrived on a Saturday evening..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "The meal was great! Our most favorite was the eggplant, salad platter, and the green curry beef. Very clean and posh restaurant. The staff are very kind...."
#                 }
#             ]
#         },
#         {
#             "name": "Ong Lam Bistro",
#             "latitude": 47.67671018851189,
#             "longitude": -122.31674049049617,
#             "children": [
#                 {
#                     "value": 5.0,
#                     "name": "We loved it. We came fresh off the plane from a trip to Vietnam and this place has all the real Vietnam vibes. They even have the hot sauce that we can only..."
#                 },
#                 {
#                     "value": 5.0,
#                     "name": "TLDR: A new must try dine in spot in Roosevelt. Beautiful ambiance. Great service. Authentic Vietnamese food that will be sure to impress.\n\nWe visited for..."
#                 },
#                 {
#                     "value": 5.0,
#                     "name": "So this Pho is probably one many are not used to.  It's North vietnamese so the broth is not as punchy.  Also will not have Sriracha and Hoisin on the table..."
#                 }
#             ]
#         },
#         {
#             "name": "Restaurant Christine",
#             "latitude": 47.66876,
#             "longitude": -122.33183,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "So far I've tried the pulled pork sammy with truffle fries, and the Zoe burger. \nAmAzing. \nSo much flavor, so much perfect mingling of textures. Decent..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "Had a perfectly lovely meal at Restaurant Christine. Casual, family friendly atmosphere that still works for a date night. \n\nSquash blossoms were the best..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "For my last review of the year and my 1,000th:), I wanted to go back to one of  my favorite meals of the year in November.  Restaurant Christine takes over..."
#                 }
#             ]
#         },
#         {
#             "name": "Tapas Lab",
#             "latitude": 47.67934,
#             "longitude": -122.32439,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "Finally tried Tapas Lab and I am very pleased! I love the small but flavor-packed bites, and they have a large selection of beer/ciders/wine/etc. to pair..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "There aren't many vegan options. I was on a date though, so we ordered vegetarian. \n\nIt is pronounced Egg-SLUT.\n\nService and ambience is exceptional. Each..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "I've been meaning to try this place for a while. I frequent the area around Tapas Lab and had once even stopped by and inquired about their food, etc., but..."
#                 }
#             ]
#         },
#         {
#             "name": "Toast Mi Green Lake",
#             "latitude": 47.68028,
#             "longitude": -122.32442,
#             "children": [
#                 {
#                     "value": 4.5,
#                     "name": "This place is AMAZING!! I've been following them on instagram for the longest time and never made it in to try out but I'm SO glad I did! I don't usually..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "Really solid banh mi! Their bread is so good, with the perfect amount of crust and fluffy inside. I had the Mekong (grilled pork) banh mi, and the pork was..."
#                 },
#                 {
#                     "value": 4.5,
#                     "name": "Super fresh & thoughtfully well prepared bahn mi! The kind attentiveness & genuine customer service is even bettah! Still eating my way down the menu & SO..."
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# Check if myYelpData has created successfully.

# %%
myYelpData
# Out:
# '{"name": "review", "children": [{"name": "Bongos", "latitude": 47.6767449533551, "longitude": -122.346925400198, "children": [{"value": 4.5, "name": "I am forever grateful to the Yelp community for helping us find this spot. It must feel like an echochamber of positive reviews for newcomers but this place..."}, {"value": 4.5, "name": "Yes, yes, this place is as good as everyone says. Trust me, I\'ve come here 3x and it was randomly closed...and I still came back to try it...and then came..."}, {"value": 4.5, "name": "After hearing such good reviews I was pleasantly surprised that this food lives up to its reputation. The veggie platter was particularly amazing for..."}]}, {"name": "Eight Row", "latitude": 47.68012, "longitude": -122.32437, "children": [{"value": 4.5, "name": "Outstanding farm to table prix fixe, seasonal tasting menus feature local ingredients from independent farms and orchards. Creative dishes incorporating the..."}, {"value": 4.5, "name": "We were so looking forward to dinner here and ultimately most of the meat dishes ended up being a disappointment. \\n\\nRockfish ceviche.  My first bite was..."}, {"value": 4.5, "name": "Lovely space, very nice servers. I\'m told it\'s women-owned and it seemed to be mostly staffed by women, which I\'m all for. My friend and I got the tasting..."}]}, {"name": "Greenlake Grill", "latitude": 47.68049, "longitude": -122.32571, "children": [{"value": 3.5, "name": "THE FOOD: absolutely delicious! All came out hot and fresh. Everything tasted amazing and was very filling. \\n\\nTHE SERVICE: this is where the 4 stars come..."}, {"value": 3.5, "name": "Been coming here now about a few times\\na month  ! That Meatloaf is incredible super friendly staff a fan !!"}, {"value": 3.5, "name": "A group of my friends and I were going out for dinner with no restaurant picked. We ended up at Greenlake Grill by walking by and seeing they didn\'t have a..."}]}, {"name": "Mkt", "latitude": 47.6686946, "longitude": -122.3329512, "children": [{"value": 4.5, "name": "Honestly, this is still one of my favorite restaurants in Seattle. The food is always delicious, the service is always great, and I love their new outdoor..."}, {"value": 4.5, "name": "I\'m an ESR fan, so I fully recognize some bias. However, I\'m a fan because the food and service is consistently great.\\n\\nDinner at Mkt last night was..."}, {"value": 4.5, "name": "Great for a dinner date or drinks/small plates after a long work week. Has a very relaxed ambiance and wonderful customer service! Been dreaming about the..."}]}, {"name": "Mykonos Greek Grill", "latitude": 47.68056, "longitude": -122.32531, "children": [{"value": 4.5, "name": "I was recommended to come here by my roommates who have raved about the food and tried it out for the first time a few weeks ago. Zarina is so sweet and I..."}, {"value": 4.5, "name": "A solid gyro, but mediocre pork souvlaki and sides. \\n\\nWe enjoyed the gyro a lot - the meat is tender and wrap comes with enough sauce and veggies to be..."}, {"value": 4.5, "name": "Mykonos is a family-run Greek restaurant in the Green Lake area. There is limited parking in the area so you might have to drive around the block a couple..."}]}, {"name": "Noi Thai Cuisine - Green Lake Seattle", "latitude": 47.6859, "longitude": -122.3373, "children": [{"value": 4.5, "name": "It is just as cute as all the social media vides are showing! It\'s so bright and modern looking inside with white and gold accented colors. It has such a..."}, {"value": 4.5, "name": "I\'d give Noi Thai 3.5 stars overall. My reviews overall lean towards the food itself, so I\'m going with a 3 here--decent.\\n\\nI arrived on a Saturday evening..."}, {"value": 4.5, "name": "The meal was great! Our most favorite was the eggplant, salad platter, and the green curry beef. Very clean and posh restaurant. The staff are very kind...."}]}, {"name": "Ong Lam Bistro", "latitude": 47.67671018851189, "longitude": -122.31674049049617, "children": [{"value" ...

# %% [markdown]
# Our data is ready to store in an physical form and download it.

# %%
from google.colab import files

with open('myYelpData.csv', 'w') as f:
  f.write(myYelpData)
  files.download('myYelpData.csv')

# %% [markdown]
# myYelpData.json should be in your download folder. Open it in a text editor and begin to develop a context of your neighborhood story.
